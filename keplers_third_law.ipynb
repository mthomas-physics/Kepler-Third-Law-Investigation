# %% [markdown]
# Investigating Keplers Third Law Using Orbital Simulations

# %% [markdown]
# Introduction
#
# Understanding orbital mechanics is essential to furthering space exploration and uncovering more about planet formation. This project will investigate how a planets orbital radius relates to its orbital period while simultaniously testing Keplers third law.

# %% [markdown]
# Research Question
#
# How does the orbital radius from the sun affect a planets orbital period?

# %% [markdown]
# Hypothesis
#
# I expect for this investigation to show that planets that have a laeger orbital radius will have a larger orbital period. In order for a planet with a larger orbital radius to have a smaller period it would need to have a larger velocity. However since the force of gravity is inversly proportional to the orbital radius the required orbital velocity would be smaller. Therefore, I expect that planets with a larger orbital radius will also have a larger orbital period.

# %% [markdown]
# Background
#
# Kepler was a mathematician who studied planetary motion and attampted to use math to explain how the planets moved. Kepler developed three laws in his lifetime the third of which states that the sqare of a planets period is proportionally related to the cube of the planets orbital radius. Keplers Third law allows us to predict the orbital period of a planet or the orbital radius if given at least one. In this investigation Keplers Third law will use a computer simulation to vary orbital radii and uncover thier resulting periods.

# %%
##Method
